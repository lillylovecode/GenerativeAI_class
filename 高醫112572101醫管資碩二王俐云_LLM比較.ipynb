# %% [markdown]
# <a href="https://colab.research.google.com/github/lillylovecode/GenerativeAI_class/blob/main/%E9%AB%98%E9%86%AB112572101%E9%86%AB%E7%AE%A1%E8%B3%87%E7%A2%A9%E4%BA%8C%E7%8E%8B%E4%BF%90%E4%BA%91_LLM%E6%AF%94%E8%BC%83.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prompt 1 : 請說明生成式ai 與 大型語言模型的不同

# %% [markdown]
# ## Gemini vs Gemma

# %% [markdown]
# 生成速度比較: Gemini 7.2s / Gemma 203.2s
# 內容豐富度：舉例、說明都大同小異，也都有舉例及表格
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Gemini vs ChatGPT

# %% [markdown]
# 相較之下，GhatGPT生成速度比Gemini慢一些，內容也短一點
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Prompt 2 : 比較GhatGPT與Gemini的不同

# %% [markdown]
# ## ChatGPT 回答
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Gemini回答
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Prompt3: 教我如何使用特徵點辨識後，進行週期分割，來分析PPG訊號

# %% [markdown]
# ## GhatGPT回答
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# GPT的回答雖然簡短，但是預處理的方式與我理解的相同，可惜沒有詳細講到週期分割怎麼做。

# %% [markdown]
# ## Gemini回答
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Gemini的回答很清楚，但我不太認同，因為週期分割應該不是用兩個波峰來進行。

# %% [markdown]
# ---

# %% [markdown]
# # 總結我的看法
#
# GhatGPT較適合做一些創意、內容生成、統整文章等，可以幫助簡化事務的複雜性。
#
# Gemini較適合收集資料、進行專業學術學習，可以將很難的東西講的比較容易。也擅長加入語音、圖片一起處理(多模態模型)

# %% [markdown]
# 總結來說，我個人比較喜歡Gemini，因為GPT有時會回答得太過簡短，變成我要問很多問題才能獲得滿意的答案。
